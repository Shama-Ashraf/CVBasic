# %% [markdown]
# <a href="https://colab.research.google.com/github/Shama-Ashraf/CVBasic/blob/main/Thesis_Anamoly_detection_in_Production_Line.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip SimpleNet-main.zip
# Out:
# Archive:  SimpleNet-main.zip
# 351a2b8d4e8cfc944dbccbf9bc6ceda930c6f26b
#    creating: SimpleNet-main/
#  extracting: SimpleNet-main/.gitignore
#   inflating: SimpleNet-main/LICENSE
#   inflating: SimpleNet-main/README.md
#  extracting: SimpleNet-main/VERSION
#   inflating: SimpleNet-main/backbones.py
#   inflating: SimpleNet-main/common.py
#    creating: SimpleNet-main/datasets/
#  extracting: SimpleNet-main/datasets/__init__.py
#    creating: SimpleNet-main/datasets/__pycache__/
#   inflating: SimpleNet-main/datasets/__pycache__/__init__.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/btad.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/cifar10.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/mvtec.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/sdd.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/sdd2.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/btad.py
# ...

# %%
# !unzip mvtec.zip.zip
# Out:
# unzip:  cannot find or open mvtec.zip.zip, mvtec.zip.zip.zip or mvtec.zip.zip.ZIP.

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content/mvtec_sleeve_dataset_v2
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# Sun Mar  8 12:07:17 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8             16W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install torch torchvision scikit-learn matplotlib tqdm pillow

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content/mvtec_sleeve_dataset_v2
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
# !unzip SimpleNet-main.zip
# Out:
# Archive:  SimpleNet-main.zip
# 351a2b8d4e8cfc944dbccbf9bc6ceda930c6f26b
#    creating: SimpleNet-main/
#  extracting: SimpleNet-main/.gitignore
#   inflating: SimpleNet-main/LICENSE
#   inflating: SimpleNet-main/README.md
#  extracting: SimpleNet-main/VERSION
#   inflating: SimpleNet-main/backbones.py
#   inflating: SimpleNet-main/common.py
#    creating: SimpleNet-main/datasets/
#  extracting: SimpleNet-main/datasets/__init__.py
#    creating: SimpleNet-main/datasets/__pycache__/
#   inflating: SimpleNet-main/datasets/__pycache__/__init__.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/btad.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/cifar10.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/mvtec.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/sdd.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/__pycache__/sdd2.cpython-38.pyc
#   inflating: SimpleNet-main/datasets/btad.py
# ...

# %%
# !unzip mvtec_sleeve_dataset_v2.zip
# Out:
# Archive:  mvtec_sleeve_dataset_v2.zip
#    creating: sleeve/
#    creating: sleeve/train/
#    creating: sleeve/train/good/
#   inflating: sleeve/train/good/WIN_20241031_09_35_31_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_36_35_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_35_21_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_35_50_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_36_25_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_36_57_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_37_06_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_37_18_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_37_26_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_37_33_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_38_25_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_38_36_Pro.png
#   inflating: sleeve/train/good/WIN_20241031_09_38_43_Pro.png
# ...

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content/mvtec_sleeve_dataset_v2
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory

# %%
# !ls
# Out:
# mvtec_sleeve_dataset_v2.zip  SimpleNet-main	 sleeve
# sample_data		     SimpleNet-main.zip

# %%
# %cd SimpleNet-main
# Out:
# /content/SimpleNet-main

# %%
# !ls
# Out:
# backbones.py  datasets	LICENSE  metrics.py  resnet.py	simplenet.py  VERSION
# common.py     imgs	main.py  README.md   run.sh	utils.py

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content/mvtec_sleeve_dataset_v2
# Out:
# 2026-03-08 12:21:48.383854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772972508.405562    3925 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772972508.412446    3925 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772972508.430661    3925 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls /content
# Out:
# mvtec_sleeve_dataset_v2.zip  SimpleNet-main	 sleeve
# sample_data		     SimpleNet-main.zip

# %%
# !ls -lh /content
# Out:
# total 84M
# -rw-r--r-- 1 root root  84M Mar  8 12:13 mvtec_sleeve_dataset_v2.zip
# drwxr-xr-x 1 root root 4.0K Feb  6 14:31 sample_data
# drwxr-xr-x 5 root root 4.0K Mar  8 12:21 SimpleNet-main
# -rw-r--r-- 1 root root 236K Mar  8 12:10 SimpleNet-main.zip
# drwxrwxr-x 5 root root 4.0K Nov 19  2024 sleeve

# %%
# !find /content -maxdepth 3 -type d | grep sleeve
# Out:
# /content/sleeve
# /content/sleeve/ground_truth
# /content/sleeve/ground_truth/bevel2
# /content/sleeve/ground_truth/bevel1
# /content/sleeve/ground_truth/scratch
# /content/sleeve/ground_truth/color
# /content/sleeve/ground_truth/dent
# /content/sleeve/train
# /content/sleeve/train/good
# /content/sleeve/test
# /content/sleeve/test/bevel2
# /content/sleeve/test/bevel1
# /content/sleeve/test/good
# /content/sleeve/test/scratch
# /content/sleeve/test/color
# /content/sleeve/test/dent

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content
# Out:
# 2026-03-08 12:27:10.520028: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772972830.541113    5332 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772972830.548144    5332 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772972830.566824    5332 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python main.py \
--gpu 0 \
--seed 0 \
--log_group simplenet_sleeve \
--log_project Sleeve_Results \
--results_path results \
--run_name sleeve_run \
net -b wideresnet50 \
-le layer2 -le layer3 \
--pretrain_embed_dimension 1536 \
--target_embed_dimension 1536 \
--patchsize 3 \
--meta_epochs 40 \
--embedding_size 256 \
--gan_epochs 4 \
--noise_std 0.015 \
--dsc_hidden 1024 \
--dsc_layers 2 \
--dsc_margin 0.5 \
--pre_proj 1 \
dataset \
--batch_size 8 \
--resize 329 \
--imagesize 288 \
-d sleeve \
mvtec /content
# Out:
# python3: can't open file '/content/main.py': [Errno 2] No such file or directory
